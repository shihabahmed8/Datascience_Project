# %% [markdown]
# # Real Estate Data Collection and Cleaning Project

# %% [markdown]
# #### •	Timeline
# ##### –	Start: Wednesday morning
# ##### –	Deadline: End of day Thursday

# %% [markdown]
# ### Project Objective
# This project is designed to simulate a real-world data science task. You will scrape property data from two real estate websites, clean and integrate the data, engineer features, and frame a predictive modeling challenge based on pricing. The final deliverable will be a GitHub repository containing all project artifacts.

# %% [markdown]
# ### Assigned Websites
# ##### You will be assigned two real estate websites. Each site contains listings for properties for rent and properties for sale.
# ##### •	Website 1: https://www.bayut.om/en/
# ##### •	Website 2: https://om.opensooq.com/en/property
#
# ### Listed properties for rent.

# %% [markdown]
# ### Project Requirements:
# ##### 1. Web Scraping
# ##### 2. Data Cleaning & Integration
# ##### 3. Feature Engineering
# ##### 4. Predictive Modeling (Challenge)
# ##### 5. GitHub Repository

# %% [markdown]
# ## Import the Libraries that I will use :

# %%
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
import re
import time

# %% [markdown]
# # 1- Web Scraping For www.bayut.om

# %%
base_url = "https://www.bayut.om"

response = requests.get(base_url, headers=headers)

if response.status_code == 200:
    print("You have the permission to use the page ✅")
else:
    print(f"Request failed with status code: {response.status_code}")
# Out:
# You have the permission to use the page ✅

# %%
response.status_code
print(f"The status code is: ",{response})
# Out:
# The status code is:  {<Response [200]>}

# %%
base_url = "https://www.bayut.om"
start_url = f"{base_url}/en/oman/properties-for-rent/"
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36'
}

properties = {
    "Title": [],
    "Location": [],
    "Price": [],
    "Size": [],
    "Listing_Type": [],
    "Link": []
}

current_page_url = start_url
page_num = 1

while True:
    print(f"Scraping page {page_num}: {current_page_url}")
    try:
        response = requests.get(current_page_url, headers=headers)
        response.raise_for_status()
    except requests.exceptions.RequestException as e:
        print(f"Error fetching page {current_page_url}: {e}")
        break

    soup = BeautifulSoup(response.text, 'html.parser')
    ads = soup.find_all('article', class_='fbc619bc')

    if not ads:
        print("No property ads found. Exiting.")
        break

    for ad in ads:
        # Title & Link
        title_tag = ad.find('a', attrs={'aria-label': 'Listing link'})
        title = title_tag['title'] if title_tag and 'title' in title_tag.attrs else None
        link = base_url + title_tag['href'] if title_tag else None
        properties["Title"].append(title)
        properties["Link"].append(link)

        # Location
        location = None
        location_tag = ad.find('div', attrs={'aria-label': 'Location'})
        if location_tag:
            location = location_tag.text.strip()
        elif title:
            match = re.search(r'in\s(.+)', title)
            if match:
                location = match.group(1)
        properties["Location"].append(location)

        # Price
        price_tag = ad.find('span', attrs={'aria-label': 'Price'})
        price = price_tag.text.strip() if price_tag else None
        properties["Price"].append(price)

        # Size (from detail page)
        size = None
        if link:
            try:
                detail_response = requests.get(link, headers=headers)
                detail_soup = BeautifulSoup(detail_response.content, 'html.parser')
                for span in detail_soup.find_all('span'):
                    text = span.get_text(strip=True)
                    if re.search(r'\d+\s*(Sq\.?\s*M\.?|sqm|m²)', text, re.I):
                        size = text
                        break
            except Exception as e:
                print(f"Error fetching size from {link}: {e}")
        properties["Size"].append(size)

        # Listing Type
        properties["Listing_Type"].append("For Rent")

    # ---- pagination ----
    next_btn = soup.find('a', title='Next')
    if next_btn and next_btn.get('href'):
        next_page_relative_url = next_btn['href']
        current_page_url = requests.compat.urljoin(base_url, next_page_relative_url)
        page_num += 1
        time.sleep(2) 
    else:
        print("No more pages found. Scraping finished.")
        break

print(f"\nTotal properties collected: {len(properties['Title'])}")

df = pd.DataFrame(properties)
df.to_csv('bayut_for_rent.csv', index=False)
# Out:
# Scraping page 1: https://www.bayut.om/en/oman/properties-for-rent/
# Scraping page 2: https://www.bayut.om/en/oman/properties-for-rent/page-2/
# Scraping page 3: https://www.bayut.om/en/oman/properties-for-rent/page-3/
# Scraping page 4: https://www.bayut.om/en/oman/properties-for-rent/page-4/
# Scraping page 5: https://www.bayut.om/en/oman/properties-for-rent/page-5/
# Scraping page 6: https://www.bayut.om/en/oman/properties-for-rent/page-6/
# Scraping page 7: https://www.bayut.om/en/oman/properties-for-rent/page-7/
# Scraping page 8: https://www.bayut.om/en/oman/properties-for-rent/page-8/
# Scraping page 9: https://www.bayut.om/en/oman/properties-for-rent/page-9/
# Scraping page 10: https://www.bayut.om/en/oman/properties-for-rent/page-10/
# Scraping page 11: https://www.bayut.om/en/oman/properties-for-rent/page-11/
# Scraping page 12: https://www.bayut.om/en/oman/properties-for-rent/page-12/
# Scraping page 13: https://www.bayut.om/en/oman/properties-for-rent/page-13/
# Scraping page 14: https://www.bayut.om/en/oman/properties-for-rent/page-14/
# Scraping page 15: https://www.bayut.om/en/oman/properties-for-rent/page-15/
# Scraping page 16: https://www.bayut.om/en/oman/properties-for-rent/page-16/
# Scraping page 17: https://www.bayut.om/en/oman/properties-for-rent/page-17/
# Scraping page 18: https://www.bayut.om/en/oman/properties-for-rent/page-18/
# Scraping page 19: https://www.bayut.om/en/oman/properties-for-rent/page-19/
# Scraping page 20: https://www.bayut.om/en/oman/properties-for-rent/page-20/
# Scraping page 21: https://www.bayut.om/en/oman/properties-for-rent/page-21/
# Scraping page 22: https://www.bayut.om/en/oman/properties-for-rent/page-22/
# Scraping page 23: https://www.bayut.om/en/oman/properties-for-rent/page-23/
# Scraping page 24: https://www.bayut.om/en/oman/properties-for-rent/page-24/
# Scraping page 25: https://www.bayut.om/en/oman/properties-for-rent/page-25/
# Scraping page 26: https://www.bayut.om/en/oman/properties-for-rent/page-26/
# Scraping page 27: https://www.bayut.om/en/oman/properties-for-rent/page-27/
# Scraping page 28: https://www.bayut.om/en/oman/properties-for-rent/page-28/
# Scraping page 29: https://www.bayut.om/en/oman/properties-for-rent/page-29/
# Scraping page 30: https://www.bayut.om/en/oman/properties-for-rent/page-30/
# Scraping page 31: https://www.bayut.om/en/oman/properties-for-rent/page-31/
# Scraping page 32: https://www.bayut.om/en/oman/properties-for-rent/page-32/
# Scraping page 33: https://www.bayut.om/en/oman/properties-for-rent/page-33/
# Scraping page 34: https://www.bayut.om/en/oman/properties-for-rent/page-34/
# Scraping page 35: https://www.bayut.om/en/oman/properties-for-rent/page-35/
# Scraping page 36: https://www.bayut.om/en/oman/properties-for-rent/page-36/
# Scraping page 37: https://www.bayut.om/en/oman/properties-for-rent/page-37/
# Scraping page 38: https://www.bayut.om/en/oman/properties-for-rent/page-38/
# Scraping page 39: https://www.bayut.om/en/oman/properties-for-rent/page-39/
# Scraping page 40: https://www.bayut.om/en/oman/properties-for-rent/page-40/
# Scraping page 41: https://www.bayut.om/en/oman/properties-for-rent/page-41/
# Scraping page 42: https://www.bayut.om/en/oman/properties-for-rent/page-42/
# Scraping page 43: https://www.bayut.om/en/oman/properties-for-rent/page-43/
# Scraping page 44: https://www.bayut.om/en/oman/properties-for-rent/page-44/
# Scraping page 45: https://www.bayut.om/en/oman/properties-for-rent/page-45/
# Scraping page 46: https://www.bayut.om/en/oman/properties-for-rent/page-46/
# Scraping page 47: https://www.bayut.om/en/oman/properties-for-rent/page-47/
# Scraping page 48: https://www.bayut.om/en/oman/properties-for-rent/page-48/
# Scraping page 49: https://www.bayut.om/en/oman/properties-for-rent/page-49/
# Scraping page 50: https://www.bayut.om/en/oman/properties-for-rent/page-50/
# Scraping page 51: https://www.bayut.om/en/oman/properties-for-rent/page-51/
# Scraping page 52: https://www.bayut.om/en/oman/properties-for-rent/page-52/
# Scraping page 53: https://www.bayut.om/en/oman/properties-for-rent/page-53/
# Scraping page 54: https://www.bayut.om/en/oman/properties-for-rent/page-54/
# Scraping page 55: https://www.bayut.om/en/oman/properties-for-rent/page-55/
# No more pages found. Scraping finished.
#
# Total properties collected: 1305

# %%
# Output as DataFrame
df = pd.DataFrame(properties)
df
# Out:
#                                                   Title  \
# 0             1 Bedroom Apartment For Rent Ruwi, Muscat
# 1          1 Bedroom Apartment For Rent Al Hail, Muscat
# 2               3 Bedrooms Villa For Rent Qurum, Muscat
# 3     4 Bedrooms Villa For Rent Madinat As Sultan Qa...
# 4     2 Bedrooms Apartment For Rent in Al Hamriyah, ...
# ...                                                 ...
# 1300  1 Bedroom Apartment For Rent in Al Duqum, Al W...
# 1301  Land for Rent - Residential Land in Barka, Al ...
# 1302  2 Bedroom Apartment For Rent Barr Al Jissah, M...
# 1303   4 Bedroom Villa For Rent in Muscat Hills, Muscat
# 1304          2 Bedroom Apartment For Rent Ruwi, Muscat
#
#                               Location  Price        Size Listing_Type  \
# 0                         Ruwi, Muscat    150   70 Sq. M.     For Rent
# 1                      Al Hail, Muscat    300  100 Sq. M.     For Rent
# 2                        Qurum, Muscat    750  300 Sq. M.     For Rent
# 3     Madinat As Sultan Qaboos, Muscat    950  300 Sq. M.     For Rent
# 4                  Al Hamriyah, Muscat    250  100 Sq. M.     For Rent
# ...                                ...    ...         ...          ...
# 1300                Al Duqum, Al Wusta     80   30 Sq. M.     For Rent
# 1301                 Barka, Al Batinah    300  619 Sq. M.     For Rent
# 1302            Barr Al Jissah, Muscat    850  200 Sq. M.     For Rent
# 1303              Muscat Hills, Muscat  1,450  419 Sq. M.     For Rent
# 1304                      Ruwi, Muscat    190   95 Sq. M.     For Rent
#
#                                                    Link
# 0     https://www.bayut.om/en/property/details-13012...
# 1     https://www.bayut.om/en/property/details-13027...
# 2     https://www.bayut.om/en/property/details-12994...
# 3     https://www.bayut.om/en/property/details-13018...
# 4     https://www.bayut.om/en/property/details-12994...
# ...                                                 ...
# 1300  https://www.bayut.om/en/property/details-13008...
# 1301  https://www.bayut.om/en/property/details-12778...
# 1302  https://www.bayut.om/en/property/details-13020...
# 1303  https://www.bayut.om/en/property/details-12991...
# 1304  https://www.bayut.om/en/property/details-13027...
#
# [1305 rows x 6 columns]

# %%
print("Scraping page link:", url)
# Out:
# Scraping page link: https://www.bayut.om/en/oman/properties-for-rent/

# %% [markdown]
# # 2- Web Scraping For om.opensooq.com

# %%
base_url = 'https://om.opensooq.com/en/property/property-for-rent'

response = requests.get(base_url, headers=headers)

if response.status_code == 200:
    print("You have the permission to use the page ✅")
else:
    print(f"Request failed with status code: {response.status_code}")
# Out:
# You have the permission to use the page ✅

# %%
response.status_code
print(f"The status code is: ",{response})
# Out:
# The status code is:  {<Response [200]>}

# %%
base_url = 'https://om.opensooq.com/en/property/property-for-rent'
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36'
}

properties = {
    "Title": [],
    "Location": [],
    "Price": [],
    "Size": [],
    "Listing_Type": [],
    "Link": []
}

page = 1
while True:
    url = f"{base_url}?page={page}"
    print(f"Scraping page {page}: {url}")
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.content, "html.parser")

    cards = soup.find_all('a', class_=lambda x: x and 'postListItemData' in x)
    if not cards:
        print("No more cards found. Stopping.")
        break

    for card in cards:
        card_text = card.get_text(separator='\n', strip=True)
        lines = card_text.split('\n')

        title = lines[2] if len(lines) > 2 else None

        location = None
        for i in range(len(lines)):
            if 'Chat' in lines[i]:
                if i >= 2:
                    location = lines[i-2] + ", " + lines[i-1]
                break

        price = lines[-1] if lines else None

        size = None
        p_tag = card.find('p')
        if p_tag:
            match = re.search(r'Surface\s*Area:\s*([0-9,]+)\s*m2', p_tag.text)
            if match:
                size = match.group(1).replace(',', '')

        listing_type = "For Rent"
        link = 'https://om.opensooq.com' + card.get('href') if card.get('href') else None

        properties["Title"].append(title)
        properties["Location"].append(location)
        properties["Price"].append(price)
        properties["Size"].append(size)
        properties["Listing_Type"].append(listing_type)
        properties["Link"].append(link)

    next_btn = soup.find('a', attrs={'data-id': 'nextPageArrow'})
    if not next_btn:
        print("No next page. Done scraping.")
        break

    page += 1
    time.sleep(1)

df = pd.DataFrame(properties)
df.to_csv('opensooq_for_rent.csv', index=False)
# Out:
# Scraping page 1: https://om.opensooq.com/en/property/property-for-rent?page=1
# Scraping page 2: https://om.opensooq.com/en/property/property-for-rent?page=2
# Scraping page 3: https://om.opensooq.com/en/property/property-for-rent?page=3
# Scraping page 4: https://om.opensooq.com/en/property/property-for-rent?page=4
# Scraping page 5: https://om.opensooq.com/en/property/property-for-rent?page=5
# Scraping page 6: https://om.opensooq.com/en/property/property-for-rent?page=6
# Scraping page 7: https://om.opensooq.com/en/property/property-for-rent?page=7
# Scraping page 8: https://om.opensooq.com/en/property/property-for-rent?page=8
# Scraping page 9: https://om.opensooq.com/en/property/property-for-rent?page=9
# Scraping page 10: https://om.opensooq.com/en/property/property-for-rent?page=10
# Scraping page 11: https://om.opensooq.com/en/property/property-for-rent?page=11
# Scraping page 12: https://om.opensooq.com/en/property/property-for-rent?page=12
# Scraping page 13: https://om.opensooq.com/en/property/property-for-rent?page=13
# Scraping page 14: https://om.opensooq.com/en/property/property-for-rent?page=14
# Scraping page 15: https://om.opensooq.com/en/property/property-for-rent?page=15
# Scraping page 16: https://om.opensooq.com/en/property/property-for-rent?page=16
# Scraping page 17: https://om.opensooq.com/en/property/property-for-rent?page=17
# Scraping page 18: https://om.opensooq.com/en/property/property-for-rent?page=18
# Scraping page 19: https://om.opensooq.com/en/property/property-for-rent?page=19
# Scraping page 20: https://om.opensooq.com/en/property/property-for-rent?page=20
# Scraping page 21: https://om.opensooq.com/en/property/property-for-rent?page=21
# Scraping page 22: https://om.opensooq.com/en/property/property-for-rent?page=22
# Scraping page 23: https://om.opensooq.com/en/property/property-for-rent?page=23
# Scraping page 24: https://om.opensooq.com/en/property/property-for-rent?page=24
# Scraping page 25: https://om.opensooq.com/en/property/property-for-rent?page=25
# Scraping page 26: https://om.opensooq.com/en/property/property-for-rent?page=26
# Scraping page 27: https://om.opensooq.com/en/property/property-for-rent?page=27
# Scraping page 28: https://om.opensooq.com/en/property/property-for-rent?page=28
# Scraping page 29: https://om.opensooq.com/en/property/property-for-rent?page=29
# Scraping page 30: https://om.opensooq.com/en/property/property-for-rent?page=30
# Scraping page 31: https://om.opensooq.com/en/property/property-for-rent?page=31
# Scraping page 32: https://om.opensooq.com/en/property/property-for-rent?page=32
# Scraping page 33: https://om.opensooq.com/en/property/property-for-rent?page=33
# Scraping page 34: https://om.opensooq.com/en/property/property-for-rent?page=34
# Scraping page 35: https://om.opensooq.com/en/property/property-for-rent?page=35
# Scraping page 36: https://om.opensooq.com/en/property/property-for-rent?page=36
# Scraping page 37: https://om.opensooq.com/en/property/property-for-rent?page=37
# Scraping page 38: https://om.opensooq.com/en/property/property-for-rent?page=38
# Scraping page 39: https://om.opensooq.com/en/property/property-for-rent?page=39
# Scraping page 40: https://om.opensooq.com/en/property/property-for-rent?page=40
# Scraping page 41: https://om.opensooq.com/en/property/property-for-rent?page=41
# Scraping page 42: https://om.opensooq.com/en/property/property-for-rent?page=42
# Scraping page 43: https://om.opensooq.com/en/property/property-for-rent?page=43
# Scraping page 44: https://om.opensooq.com/en/property/property-for-rent?page=44
# Scraping page 45: https://om.opensooq.com/en/property/property-for-rent?page=45
# Scraping page 46: https://om.opensooq.com/en/property/property-for-rent?page=46
# Scraping page 47: https://om.opensooq.com/en/property/property-for-rent?page=47
# Scraping page 48: https://om.opensooq.com/en/property/property-for-rent?page=48
# Scraping page 49: https://om.opensooq.com/en/property/property-for-rent?page=49
# Scraping page 50: https://om.opensooq.com/en/property/property-for-rent?page=50
# Scraping page 51: https://om.opensooq.com/en/property/property-for-rent?page=51
# Scraping page 52: https://om.opensooq.com/en/property/property-for-rent?page=52
# Scraping page 53: https://om.opensooq.com/en/property/property-for-rent?page=53
# Scraping page 54: https://om.opensooq.com/en/property/property-for-rent?page=54
# Scraping page 55: https://om.opensooq.com/en/property/property-for-rent?page=55
# Scraping page 56: https://om.opensooq.com/en/property/property-for-rent?page=56
# Scraping page 57: https://om.opensooq.com/en/property/property-for-rent?page=57
# Scraping page 58: https://om.opensooq.com/en/property/property-for-rent?page=58
# Scraping page 59: https://om.opensooq.com/en/property/property-for-rent?page=59
# Scraping page 60: https://om.opensooq.com/en/property/property-for-rent?page=60
# Scraping page 61: https://om.opensooq.com/en/property/property-for-rent?page=61
# Scraping page 62: https://om.opensooq.com/en/property/property-for-rent?page=62
# Scraping page 63: https://om.opensooq.com/en/property/property-for-rent?page=63
# Scraping page 64: https://om.opensooq.com/en/property/property-for-rent?page=64
# Scraping page 65: https://om.opensooq.com/en/property/property-for-rent?page=65
# Scraping page 66: https://om.opensooq.com/en/property/property-for-rent?page=66
# Scraping page 67: https://om.opensooq.com/en/property/property-for-rent?page=67
# Scraping page 68: https://om.opensooq.com/en/property/property-for-rent?page=68
# Scraping page 69: https://om.opensooq.com/en/property/property-for-rent?page=69
# Scraping page 70: https://om.opensooq.com/en/property/property-for-rent?page=70
# Scraping page 71: https://om.opensooq.com/en/property/property-for-rent?page=71
# Scraping page 72: https://om.opensooq.com/en/property/property-for-rent?page=72
# Scraping page 73: https://om.opensooq.com/en/property/property-for-rent?page=73
# Scraping page 74: https://om.opensooq.com/en/property/property-for-rent?page=74
# Scraping page 75: https://om.opensooq.com/en/property/property-for-rent?page=75
# Scraping page 76: https://om.opensooq.com/en/property/property-for-rent?page=76
# Scraping page 77: https://om.opensooq.com/en/property/property-for-rent?page=77
# Scraping page 78: https://om.opensooq.com/en/property/property-for-rent?page=78
# Scraping page 79: https://om.opensooq.com/en/property/property-for-rent?page=79
# Scraping page 80: https://om.opensooq.com/en/property/property-for-rent?page=80
# Scraping page 81: https://om.opensooq.com/en/property/property-for-rent?page=81
# Scraping page 82: https://om.opensooq.com/en/property/property-for-rent?page=82
# Scraping page 83: https://om.opensooq.com/en/property/property-for-rent?page=83
# Scraping page 84: https://om.opensooq.com/en/property/property-for-rent?page=84
# Scraping page 85: https://om.opensooq.com/en/property/property-for-rent?page=85
# Scraping page 86: https://om.opensooq.com/en/property/property-for-rent?page=86
# Scraping page 87: https://om.opensooq.com/en/property/property-for-rent?page=87
# Scraping page 88: https://om.opensooq.com/en/property/property-for-rent?page=88
# Scraping page 89: https://om.opensooq.com/en/property/property-for-rent?page=89
# Scraping page 90: https://om.opensooq.com/en/property/property-for-rent?page=90
# Scraping page 91: https://om.opensooq.com/en/property/property-for-rent?page=91
# Scraping page 92: https://om.opensooq.com/en/property/property-for-rent?page=92
# Scraping page 93: https://om.opensooq.com/en/property/property-for-rent?page=93
# Scraping page 94: https://om.opensooq.com/en/property/property-for-rent?page=94
# Scraping page 95: https://om.opensooq.com/en/property/property-for-rent?page=95
# Scraping page 96: https://om.opensooq.com/en/property/property-for-rent?page=96
# Scraping page 97: https://om.opensooq.com/en/property/property-for-rent?page=97
# Scraping page 98: https://om.opensooq.com/en/property/property-for-rent?page=98
# Scraping page 99: https://om.opensooq.com/en/property/property-for-rent?page=99
# Scraping page 100: https://om.opensooq.com/en/property/property-for-rent?page=100
# Scraping page 101: https://om.opensooq.com/en/property/property-for-rent?page=101
# Scraping page 102: https://om.opensooq.com/en/property/property-for-rent?page=102
# Scraping page 103: https://om.opensooq.com/en/property/property-for-rent?page=103
# Scraping page 104: https://om.opensooq.com/en/property/property-for-rent?page=104
# Scraping page 105: https://om.opensooq.com/en/property/property-for-rent?page=105
# Scraping page 106: https://om.opensooq.com/en/property/property-for-rent?page=106
# Scraping page 107: https://om.opensooq.com/en/property/property-for-rent?page=107
# Scraping page 108: https://om.opensooq.com/en/property/property-for-rent?page=108
# Scraping page 109: https://om.opensooq.com/en/property/property-for-rent?page=109
# Scraping page 110: https://om.opensooq.com/en/property/property-for-rent?page=110
# Scraping page 111: https://om.opensooq.com/en/property/property-for-rent?page=111
# Scraping page 112: https://om.opensooq.com/en/property/property-for-rent?page=112
# Scraping page 113: https://om.opensooq.com/en/property/property-for-rent?page=113
# Scraping page 114: https://om.opensooq.com/en/property/property-for-rent?page=114
# Scraping page 115: https://om.opensooq.com/en/property/property-for-rent?page=115
# Scraping page 116: https://om.opensooq.com/en/property/property-for-rent?page=116
# Scraping page 117: https://om.opensooq.com/en/property/property-for-rent?page=117
# Scraping page 118: https://om.opensooq.com/en/property/property-for-rent?page=118
# Scraping page 119: https://om.opensooq.com/en/property/property-for-rent?page=119
# Scraping page 120: https://om.opensooq.com/en/property/property-for-rent?page=120
# Scraping page 121: https://om.opensooq.com/en/property/property-for-rent?page=121
# Scraping page 122: https://om.opensooq.com/en/property/property-for-rent?page=122
# Scraping page 123: https://om.opensooq.com/en/property/property-for-rent?page=123
# Scraping page 124: https://om.opensooq.com/en/property/property-for-rent?page=124
# Scraping page 125: https://om.opensooq.com/en/property/property-for-rent?page=125
# Scraping page 126: https://om.opensooq.com/en/property/property-for-rent?page=126
# Scraping page 127: https://om.opensooq.com/en/property/property-for-rent?page=127
# Scraping page 128: https://om.opensooq.com/en/property/property-for-rent?page=128
# Scraping page 129: https://om.opensooq.com/en/property/property-for-rent?page=129
# Scraping page 130: https://om.opensooq.com/en/property/property-for-rent?page=130
# Scraping page 131: https://om.opensooq.com/en/property/property-for-rent?page=131
# Scraping page 132: https://om.opensooq.com/en/property/property-for-rent?page=132
# Scraping page 133: https://om.opensooq.com/en/property/property-for-rent?page=133
# Scraping page 134: https://om.opensooq.com/en/property/property-for-rent?page=134
# Scraping page 135: https://om.opensooq.com/en/property/property-for-rent?page=135
# Scraping page 136: https://om.opensooq.com/en/property/property-for-rent?page=136
# Scraping page 137: https://om.opensooq.com/en/property/property-for-rent?page=137
# Scraping page 138: https://om.opensooq.com/en/property/property-for-rent?page=138
# Scraping page 139: https://om.opensooq.com/en/property/property-for-rent?page=139
# Scraping page 140: https://om.opensooq.com/en/property/property-for-rent?page=140
# Scraping page 141: https://om.opensooq.com/en/property/property-for-rent?page=141
# Scraping page 142: https://om.opensooq.com/en/property/property-for-rent?page=142
# Scraping page 143: https://om.opensooq.com/en/property/property-for-rent?page=143
# Scraping page 144: https://om.opensooq.com/en/property/property-for-rent?page=144
# Scraping page 145: https://om.opensooq.com/en/property/property-for-rent?page=145
# Scraping page 146: https://om.opensooq.com/en/property/property-for-rent?page=146
# Scraping page 147: https://om.opensooq.com/en/property/property-for-rent?page=147
# Scraping page 148: https://om.opensooq.com/en/property/property-for-rent?page=148
# Scraping page 149: https://om.opensooq.com/en/property/property-for-rent?page=149
# Scraping page 150: https://om.opensooq.com/en/property/property-for-rent?page=150
# Scraping page 151: https://om.opensooq.com/en/property/property-for-rent?page=151
# Scraping page 152: https://om.opensooq.com/en/property/property-for-rent?page=152
# Scraping page 153: https://om.opensooq.com/en/property/property-for-rent?page=153
# Scraping page 154: https://om.opensooq.com/en/property/property-for-rent?page=154
# Scraping page 155: https://om.opensooq.com/en/property/property-for-rent?page=155
# Scraping page 156: https://om.opensooq.com/en/property/property-for-rent?page=156
# Scraping page 157: https://om.opensooq.com/en/property/property-for-rent?page=157
# Scraping page 158: https://om.opensooq.com/en/property/property-for-rent?page=158
# Scraping page 159: https://om.opensooq.com/en/property/property-for-rent?page=159
# Scraping page 160: https://om.opensooq.com/en/property/property-for-rent?page=160
# Scraping page 161: https://om.opensooq.com/en/property/property-for-rent?page=161
# Scraping page 162: https://om.opensooq.com/en/property/property-for-rent?page=162
# Scraping page 163: https://om.opensooq.com/en/property/property-for-rent?page=163
# Scraping page 164: https://om.opensooq.com/en/property/property-for-rent?page=164
# Scraping page 165: https://om.opensooq.com/en/property/property-for-rent?page=165
# Scraping page 166: https://om.opensooq.com/en/property/property-for-rent?page=166
# Scraping page 167: https://om.opensooq.com/en/property/property-for-rent?page=167
# Scraping page 168: https://om.opensooq.com/en/property/property-for-rent?page=168
# Scraping page 169: https://om.opensooq.com/en/property/property-for-rent?page=169
# Scraping page 170: https://om.opensooq.com/en/property/property-for-rent?page=170
# Scraping page 171: https://om.opensooq.com/en/property/property-for-rent?page=171
# Scraping page 172: https://om.opensooq.com/en/property/property-for-rent?page=172
# Scraping page 173: https://om.opensooq.com/en/property/property-for-rent?page=173
# Scraping page 174: https://om.opensooq.com/en/property/property-for-rent?page=174
# Scraping page 175: https://om.opensooq.com/en/property/property-for-rent?page=175
# Scraping page 176: https://om.opensooq.com/en/property/property-for-rent?page=176
# Scraping page 177: https://om.opensooq.com/en/property/property-for-rent?page=177
# Scraping page 178: https://om.opensooq.com/en/property/property-for-rent?page=178
# Scraping page 179: https://om.opensooq.com/en/property/property-for-rent?page=179
# Scraping page 180: https://om.opensooq.com/en/property/property-for-rent?page=180
# Scraping page 181: https://om.opensooq.com/en/property/property-for-rent?page=181
# Scraping page 182: https://om.opensooq.com/en/property/property-for-rent?page=182
# Scraping page 183: https://om.opensooq.com/en/property/property-for-rent?page=183
# Scraping page 184: https://om.opensooq.com/en/property/property-for-rent?page=184
# No more cards found. Stopping.

# %%
# Output as DataFrame
df = pd.DataFrame(properties)
df
# Out:
#                                                   Title  \
# 0     80 m2 2 Bedrooms Apartments for Rent in Dhofar...
# 1     عقود ايجار مكاتب مؤقتة وترخيص الانشطة Temporar...
# 2     2 Bedrooms Chalet for Rent in Al Dakhiliya Bidbid
# 3     100 m2 2 Bedrooms Apartments for Rent in Dhofa...
# 4                      Furnished Daily in Dhofar Salala
# ...                                                 ...
# 5471                 Flat for rent (inclusive of bills)
# 5472  Apartment for sharing only for working ladies ...
# 5473  160 m2 2 Bedrooms Apartments for Rent in Musca...
# 5474  30 m2 Studio Apartments for Rent in Muscat Al ...
# 5475  210 m2 2 Bedrooms Apartments for Rent in Musca...
#
#                      Location    Price  Size Listing_Type  \
# 0          , Salala, 922133XX   35 OMR    80     For Rent
# 1          , Amerat, 955469XX   75 OMR    20     For Rent
# 2          , Bidbid, 966934XX   40 OMR   220     For Rent
# 3          , Salala, 713317XX   20 OMR   100     For Rent
# 4          , Salala, 990838XX   50 OMR  None     For Rent
# ...                       ...      ...   ...          ...
# 5471  , Al Maabilah, 972922XX  175 OMR    90     For Rent
# 5472       , Bosher, 944697XX  110 OMR    50     For Rent
# 5473  , Al Maabilah, 791585XX  250 OMR   160     For Rent
# 5474   , Al Mawaleh, 727503XX  120 OMR    30     For Rent
# 5475         , Seeb, 988204XX  140 OMR   210     For Rent
#
#                                              Link
# 0     https://om.opensooq.com/en/search/266056301
# 1     https://om.opensooq.com/en/search/263485983
# 2     https://om.opensooq.com/en/search/259878571
# 3     https://om.opensooq.com/en/search/266550047
# 4     https://om.opensooq.com/en/search/266121233
# ...                                           ...
# 5471  https://om.opensooq.com/en/search/266829563
# 5472  https://om.opensooq.com/en/search/267019863
# 5473  https://om.opensooq.com/en/search/266841899
# 5474  https://om.opensooq.com/en/search/267035849
# 5475  https://om.opensooq.com/en/search/267023419
#
# [5476 rows x 6 columns]
