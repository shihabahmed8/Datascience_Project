# %% [markdown]
# # 3- Marg the two databases before cleaning:

# %%
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
import re
import time

# %%
df_bayut = pd.read_csv('bayut_for_rent.csv')
df_opensooq = pd.read_csv('opensooq_for_rent.csv')


print("Bayut columns:", df_bayut.columns.tolist())
print("OpenSooq columns:", df_opensooq.columns.tolist())


df_merged = pd.concat([df_bayut, df_opensooq], ignore_index=True)


df_merged.to_csv('properties_combined_raw2.csv', index=False, encoding='utf-8-sig')

print(f"Combined data shape: {df_merged.shape}")
print("Combined file saved as: properties_combined_raw.csv")
# Out:
# Bayut columns: ['Title', 'Location', 'Price', 'Size', 'Listing_Type', 'Link']
# OpenSooq columns: ['Title', 'Location', 'Price', 'Size', 'Listing_Type', 'Link']
# Combined data shape: (6783, 6)
# Combined file saved as: properties_combined_raw.csv

# %% [markdown]
# # 4- Now we can start cleaning the merged data.

# %%
df = pd.read_csv('properties_combined_raw2.csv')

# %%
df.head()
# Out:
#                                                Title  \
# 0          1 Bedroom Apartment For Rent Ruwi, Muscat
# 1       1 Bedroom Apartment For Rent Al Hail, Muscat
# 2            3 Bedrooms Villa For Rent Qurum, Muscat
# 3  4 Bedrooms Villa For Rent Madinat As Sultan Qa...
# 4  2 Bedrooms Apartment For Rent in Al Hamriyah, ...
#
#                            Location Price        Size Listing_Type  \
# 0                      Ruwi, Muscat   150   70 Sq. M.     For Rent
# 1                   Al Hail, Muscat   300  100 Sq. M.     For Rent
# 2                     Qurum, Muscat   750  300 Sq. M.     For Rent
# 3  Madinat As Sultan Qaboos, Muscat   950  300 Sq. M.     For Rent
# 4               Al Hamriyah, Muscat   250  100 Sq. M.     For Rent
#
#                                                 Link
# 0  https://www.bayut.om/en/property/details-13012...
# 1  https://www.bayut.om/en/property/details-13027...
# 2  https://www.bayut.om/en/property/details-12994...
# 3  https://www.bayut.om/en/property/details-13018...
# 4  https://www.bayut.om/en/property/details-12994...

# %%
df.columns
# Out:
# Index(['Title', 'Location', 'Price', 'Size', 'Listing_Type', 'Link'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6783 entries, 0 to 6782
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Title         6783 non-null   object
#  1   Location      6729 non-null   object
#  2   Price         6783 non-null   object
#  3   Size          5634 non-null   object
#  4   Listing_Type  6783 non-null   object
#  5   Link          6783 non-null   object
# dtypes: object(6)
# memory usage: 318.1+ KB

# %%
df.dtypes
# Out:
# Title           object
# Location        object
# Price           object
# Size            object
# Listing_Type    object
# Link            object
# dtype: object

# %%
df
# Out:
#                                                   Title  \
# 0             1 Bedroom Apartment For Rent Ruwi, Muscat
# 1          1 Bedroom Apartment For Rent Al Hail, Muscat
# 2               3 Bedrooms Villa For Rent Qurum, Muscat
# 3     4 Bedrooms Villa For Rent Madinat As Sultan Qa...
# 4     2 Bedrooms Apartment For Rent in Al Hamriyah, ...
# ...                                                 ...
# 6778  500 m2 Studio Apartments for Rent in Muscat Al...
# 6779  Fully Furnished 1BHK Flat for Rent – Bareeq Al...
# 6780  125 m2 2 Bedrooms Apartments for Rent in Musca...
# 6781                  2BHK Apartment for rent - Bousher
# 6782  280 m2 4 Bedrooms Villa for Rent in Muscat Bosher
#
#                               Location    Price        Size Listing_Type  \
# 0                         Ruwi, Muscat      150   70 Sq. M.     For Rent
# 1                      Al Hail, Muscat      300  100 Sq. M.     For Rent
# 2                        Qurum, Muscat      750  300 Sq. M.     For Rent
# 3     Madinat As Sultan Qaboos, Muscat      950  300 Sq. M.     For Rent
# 4                  Al Hamriyah, Muscat      250  100 Sq. M.     For Rent
# ...                                ...      ...         ...          ...
# 6778            , Al Khuwair, 760832XX  180 OMR       500.0     For Rent
# 6779                  , Qurm, 905099XX  440 OMR        90.0     For Rent
# 6780                 , Ghala, 994886XX  230 OMR       125.0     For Rent
# 6781                , Bosher, 992220XX  270 OMR        80.0     For Rent
# 6782                , Bosher, 977402XX  950 OMR       280.0     For Rent
#
#                                                    Link
# 0     https://www.bayut.om/en/property/details-13012...
# 1     https://www.bayut.om/en/property/details-13027...
# 2     https://www.bayut.om/en/property/details-12994...
# 3     https://www.bayut.om/en/property/details-13018...
# 4     https://www.bayut.om/en/property/details-12994...
# ...                                                 ...
# 6778        https://om.opensooq.com/en/search/266994539
# 6779        https://om.opensooq.com/en/search/266949055
# 6780        https://om.opensooq.com/en/search/265445187
# 6781        https://om.opensooq.com/en/search/267036337
# 6782        https://om.opensooq.com/en/search/266989343
#
# [6783 rows x 6 columns]

# %%
print(df.isnull().sum())
# Out:
# Title              0
# Location          54
# Price              0
# Size            1149
# Listing_Type       0
# Link               0
# dtype: int64

# %%
df[df['Location'].isna()]
# Out:
#                                                   Title Location      Price  \
# 1614                Unfurnished Monthly in Muscat Ansab      NaN    110 OMR
# 1621           Unfurnished Monthly in Muscat Al Mawaleh      NaN     95 OMR
# 1625        Semi Furnished Monthly in Muscat Al Mawaleh      NaN    130 OMR
# 1640   2 Bedroom Apartment in Al Ghubra - Bait Abdullah      NaN    225 OMR
# 1641   3 Bedroom Apartment for Rent at Ruwi - Mudhaireb      NaN    250 OMR
# 1642            Semi Furnished Monthly in Muscat Bosher      NaN    110 OMR
# 1643  Furnished 2 Bedroom Apartment with Maid Room a...      NaN    340 OMR
# 1644  Apartment for Rent with 2 Bedrooms at Ruwi MBD...      NaN    200 OMR
# 1648           Semi Furnished Monthly in Muscat Al-Hail      NaN     90 OMR
# 1649    Apartment for Rent with 1 Bedroom at Ruwi - REX      NaN    140 OMR
# 1651                 Furnished Monthly in Muscat Bosher      NaN    100 OMR
# 1653  3 Bedroom Apartment at Al Maabilah - Baraq Al ...      NaN    210 OMR
# 1656  Commercial Apartment for Rent with 1 Room at A...      NaN    180 OMR
# 1662           Semi Furnished Monthly in Muscat Al-Hail      NaN     90 OMR
# 1702             Semi Furnished Monthly in Muscat Ansab      NaN    100 OMR
# 1798          Semi Furnished Monthly in Muscat Al Khoud      NaN    100 OMR
# 1800             Furnished Monthly in Muscat Al Mawaleh      NaN    120 OMR
# 1941           Unfurnished Monthly in Muscat Al Khuwair      NaN    110 OMR
# 2414                Unfurnished Monthly in Muscat Ansab      NaN    110 OMR
# 2424           Unfurnished Monthly in Muscat Al Mawaleh      NaN     95 OMR
# 2429        Semi Furnished Monthly in Muscat Al Mawaleh      NaN    130 OMR
# 2451   2 Bedroom Apartment in Al Ghubra - Bait Abdullah      NaN    225 OMR
# 2453   3 Bedroom Apartment for Rent at Ruwi - Mudhaireb      NaN    250 OMR
# 2454            Semi Furnished Monthly in Muscat Bosher      NaN    110 OMR
# 2455  Furnished 2 Bedroom Apartment with Maid Room a...      NaN    340 OMR
# 2456  Apartment for Rent with 2 Bedrooms at Ruwi MBD...      NaN    200 OMR
# 2460           Semi Furnished Monthly in Muscat Al-Hail      NaN     90 OMR
# 2461    Apartment for Rent with 1 Bedroom at Ruwi - REX      NaN    140 OMR
# 2463                 Furnished Monthly in Muscat Bosher      NaN    100 OMR
# 2465  3 Bedroom Apartment at Al Maabilah - Baraq Al ...      NaN    210 OMR
# 2468  Commercial Apartment for Rent with 1 Room at A...      NaN    180 OMR
# 2477           Semi Furnished Monthly in Muscat Al-Hail      NaN     90 OMR
# 2547             Semi Furnished Monthly in Muscat Ansab      NaN    100 OMR
# 2692          Semi Furnished Monthly in Muscat Al Khoud      NaN    100 OMR
# 2694             Furnished Monthly in Muscat Al Mawaleh      NaN    120 OMR
# 3243    2 Bedroom Apartment at CBD Ruwi - Hala Building      NaN    150 OMR
# 3245  Apartment for Rent with 2 Bedrooms at Al Khoud...      NaN    160 OMR
# 3246          1BR + 2BR Apartments at Al Khuwair - Sala      NaN    150 OMR
# 3248  Apartment for Rent with 1 Bedroom at Wadi Al K...      NaN    165 OMR
# 3249  Apartment for Rent with 1 Bedroom at Ruwi - Al...      NaN    150 OMR
# 3250  Apartment for Rent with 1 or 2 Bedrooms in Wad...      NaN    130 OMR
# 3251  Brand New Commercial Space for Rent near at Al...      NaN     12 OMR
# 3254  Apartment for Rent with 2 Bedrooms Apartment a...      NaN    250 OMR
# 3255  2 Bedroom Apartment for Rent in Al Qurum - But...      NaN    250 OMR
# 3678                 Furnished Monthly in Muscat Bosher      NaN    100 OMR
# 3693           Unfurnished Monthly in Muscat Al Mawaleh      NaN    100 OMR
# 3696        Semi Furnished Monthly in Muscat Al Mawaleh      NaN    130 OMR
# 3958  محل تجاري للإيجار بشارع 18 نوفمبر بالعذيبة، Re...      NaN    550 OMR
# 4128             Semi Furnished Monthly in Muscat Ansab      NaN    110 OMR
# 4243        مبنى للايجار قريب من الميناء مواقف الى شارع      NaN  1,000 OMR
# 4364                 Furnished Monthly in Muscat Azaiba      NaN    150 OMR
# 4859           Unfurnished Monthly in Muscat Al Mawaleh      NaN    100 OMR
# 5570                   Furnished Daily in Dhofar Salala      NaN     45 OMR
# 5699           Unfurnished Monthly in Muscat Al Khuwair      NaN    110 OMR
#
#        Size Listing_Type                                         Link
# 1614    NaN     For Rent  https://om.opensooq.com/en/search/266950819
# 1621    NaN     For Rent  https://om.opensooq.com/en/search/264139289
# 1625    NaN     For Rent  https://om.opensooq.com/en/search/264995631
# 1640   78.0     For Rent  https://om.opensooq.com/en/search/266842689
# 1641   92.0     For Rent  https://om.opensooq.com/en/search/266842323
# 1642    NaN     For Rent  https://om.opensooq.com/en/search/265881111
# 1643   92.0     For Rent  https://om.opensooq.com/en/search/266841347
# 1644   72.0     For Rent  https://om.opensooq.com/en/search/266841699
# 1648    NaN     For Rent  https://om.opensooq.com/en/search/265880191
# 1649   63.0     For Rent  https://om.opensooq.com/en/search/266841753
# 1651    NaN     For Rent  https://om.opensooq.com/en/search/266394021
# 1653  100.0     For Rent  https://om.opensooq.com/en/search/266842519
# 1656   69.0     For Rent  https://om.opensooq.com/en/search/266892175
# 1662    NaN     For Rent  https://om.opensooq.com/en/search/264254095
# 1702    NaN     For Rent  https://om.opensooq.com/en/search/264995045
# 1798    NaN     For Rent  https://om.opensooq.com/en/search/265880373
# 1800    NaN     For Rent  https://om.opensooq.com/en/search/264981619
# 1941    NaN     For Rent  https://om.opensooq.com/en/search/266034241
# 2414    NaN     For Rent  https://om.opensooq.com/en/search/266950819
# 2424    NaN     For Rent  https://om.opensooq.com/en/search/264139289
# 2429    NaN     For Rent  https://om.opensooq.com/en/search/264995631
# 2451   78.0     For Rent  https://om.opensooq.com/en/search/266842689
# 2453   92.0     For Rent  https://om.opensooq.com/en/search/266842323
# 2454    NaN     For Rent  https://om.opensooq.com/en/search/265881111
# 2455   92.0     For Rent  https://om.opensooq.com/en/search/266841347
# 2456   72.0     For Rent  https://om.opensooq.com/en/search/266841699
# 2460    NaN     For Rent  https://om.opensooq.com/en/search/265880191
# 2461   63.0     For Rent  https://om.opensooq.com/en/search/266841753
# 2463    NaN     For Rent  https://om.opensooq.com/en/search/266394021
# 2465  100.0     For Rent  https://om.opensooq.com/en/search/266842519
# 2468   69.0     For Rent  https://om.opensooq.com/en/search/266892175
# 2477    NaN     For Rent  https://om.opensooq.com/en/search/264254095
# 2547    NaN     For Rent  https://om.opensooq.com/en/search/264995045
# 2692    NaN     For Rent  https://om.opensooq.com/en/search/265880373
# 2694    NaN     For Rent  https://om.opensooq.com/en/search/264981619
# 3243   76.0     For Rent  https://om.opensooq.com/en/search/266842179
# 3245   75.0     For Rent  https://om.opensooq.com/en/search/266842057
# 3246  100.0     For Rent  https://om.opensooq.com/en/search/266841919
# 3248   63.0     For Rent  https://om.opensooq.com/en/search/266841807
# 3249   86.0     For Rent  https://om.opensooq.com/en/search/266841625
# 3250  108.0     For Rent  https://om.opensooq.com/en/search/266841587
# 3251  300.0     For Rent  https://om.opensooq.com/en/search/266841555
# 3254  110.0     For Rent  https://om.opensooq.com/en/search/266841477
# 3255   89.0     For Rent  https://om.opensooq.com/en/search/266841425
# 3678    NaN     For Rent  https://om.opensooq.com/en/search/266392961
# 3693    NaN     For Rent  https://om.opensooq.com/en/search/263822415
# 3696    NaN     For Rent  https://om.opensooq.com/en/search/265087347
# 3958   58.0     For Rent  https://om.opensooq.com/en/search/263373289
# 4128    NaN     For Rent  https://om.opensooq.com/en/search/265880839
# 4243    1.0     For Rent  https://om.opensooq.com/en/search/265986745
# 4364    NaN     For Rent  https://om.opensooq.com/en/search/265832449
# 4859    NaN     For Rent  https://om.opensooq.com/en/search/264244759
# 5570    NaN     For Rent  https://om.opensooq.com/en/search/266078775
# 5699    NaN     For Rent  https://om.opensooq.com/en/search/266034241

# %%
def extract_location_from_title(title):
    
    import re
    match = re.search(r'(?:in|at)\s+(.+)$', str(title))
    if match:
        return match.group(1).strip()
    return np.nan


df['Location'] = df.apply(
    lambda row: extract_location_from_title(row['Title']) if pd.isna(row['Location']) else row['Location'],
    axis=1
)

# %%
df[df['Location'].isna()]
# Out:
#                                             Title Location      Price Size  \
# 4243  مبنى للايجار قريب من الميناء مواقف الى شارع      NaN  1,000 OMR  1.0
#
#      Listing_Type                                         Link
# 4243     For Rent  https://om.opensooq.com/en/search/265986745

# %%
df = df.dropna(subset=['Location'])

# %%
print(df.isnull().sum())
# Out:
# Title              0
# Location           0
# Price              0
# Size            1149
# Listing_Type       0
# Link               0
# dtype: int64

# %%
df['Size_unit'] = df['Size'].str.extract(r'([^\d.]+)$')[0].str.strip()


cols = list(df.columns)
cols.insert(cols.index('Size') + 1, cols.pop(cols.index('Size_unit')))
df = df[cols]
# Out:
# C:\Users\bbuser\AppData\Local\Temp\ipykernel_9012\719921161.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Size_unit'] = df['Size'].str.extract(r'([^\d.]+)$')[0].str.strip()

# %%
print(df.isnull().sum())
# Out:
# Title              0
# Location           0
# Price              0
# Size            1149
# Size_unit       6782
# Listing_Type       0
# Link               0
# dtype: int64

# %%
df['Size_unit'].fillna('Sq. M.', inplace=True)
# Out:
# C:\Users\bbuser\AppData\Local\Temp\ipykernel_9012\463848599.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Size_unit'].fillna('Sq. M.', inplace=True)

# %%
print(df.isnull().sum())
# Out:
# Title              0
# Location           0
# Price              0
# Size            1149
# Size_unit          0
# Listing_Type       0
# Link               0
# dtype: int64

# %%
df['Size'].str.extract(r'([\d.]+)').astype(float)
# Out:
#           0
# 0      70.0
# 1     100.0
# 2     300.0
# 3     300.0
# 4     100.0
# ...     ...
# 6778  500.0
# 6779   90.0
# 6780  125.0
# 6781   80.0
# 6782  280.0
#
# [6782 rows x 1 columns]

# %%
df
# Out:
#                                                   Title  \
# 0             1 Bedroom Apartment For Rent Ruwi, Muscat
# 1          1 Bedroom Apartment For Rent Al Hail, Muscat
# 2               3 Bedrooms Villa For Rent Qurum, Muscat
# 3     4 Bedrooms Villa For Rent Madinat As Sultan Qa...
# 4     2 Bedrooms Apartment For Rent in Al Hamriyah, ...
# ...                                                 ...
# 6778  500 m2 Studio Apartments for Rent in Muscat Al...
# 6779  Fully Furnished 1BHK Flat for Rent – Bareeq Al...
# 6780  125 m2 2 Bedrooms Apartments for Rent in Musca...
# 6781                  2BHK Apartment for rent - Bousher
# 6782  280 m2 4 Bedrooms Villa for Rent in Muscat Bosher
#
#                               Location    Price        Size Size_unit  \
# 0                         Ruwi, Muscat      150   70 Sq. M.    Sq. M.
# 1                      Al Hail, Muscat      300  100 Sq. M.    Sq. M.
# 2                        Qurum, Muscat      750  300 Sq. M.    Sq. M.
# 3     Madinat As Sultan Qaboos, Muscat      950  300 Sq. M.    Sq. M.
# 4                  Al Hamriyah, Muscat      250  100 Sq. M.    Sq. M.
# ...                                ...      ...         ...       ...
# 6778            , Al Khuwair, 760832XX  180 OMR       500.0    Sq. M.
# 6779                  , Qurm, 905099XX  440 OMR        90.0    Sq. M.
# 6780                 , Ghala, 994886XX  230 OMR       125.0    Sq. M.
# 6781                , Bosher, 992220XX  270 OMR        80.0    Sq. M.
# 6782                , Bosher, 977402XX  950 OMR       280.0    Sq. M.
#
#      Listing_Type                                               Link
# 0        For Rent  https://www.bayut.om/en/property/details-13012...
# 1        For Rent  https://www.bayut.om/en/property/details-13027...
# 2        For Rent  https://www.bayut.om/en/property/details-12994...
# 3        For Rent  https://www.bayut.om/en/property/details-13018...
# 4        For Rent  https://www.bayut.om/en/property/details-12994...
# ...           ...                                                ...
# 6778     For Rent        https://om.opensooq.com/en/search/266994539
# 6779     For Rent        https://om.opensooq.com/en/search/266949055
# 6780     For Rent        https://om.opensooq.com/en/search/265445187
# 6781     For Rent        https://om.opensooq.com/en/search/267036337
# 6782     For Rent        https://om.opensooq.com/en/search/266989343
#
# [6782 rows x 7 columns]

# %%
df.dtypes
# Out:
# Title           object
# Location        object
# Price           object
# Size            object
# Size_unit       object
# Listing_Type    object
# Link            object
# dtype: object

# %%
df['Size'] = df['Size'].str.extract(r'([\d.]+)') 
df['Size'] = df['Size'].astype(float)

# %%
df.dtypes
# Out:
# Title            object
# Location         object
# Price            object
# Size            float64
# Size_unit        object
# Listing_Type     object
# Link             object
# dtype: object

# %%
df
# Out:
#                                                   Title  \
# 0             1 Bedroom Apartment For Rent Ruwi, Muscat
# 1          1 Bedroom Apartment For Rent Al Hail, Muscat
# 2               3 Bedrooms Villa For Rent Qurum, Muscat
# 3     4 Bedrooms Villa For Rent Madinat As Sultan Qa...
# 4     2 Bedrooms Apartment For Rent in Al Hamriyah, ...
# ...                                                 ...
# 6778  500 m2 Studio Apartments for Rent in Muscat Al...
# 6779  Fully Furnished 1BHK Flat for Rent – Bareeq Al...
# 6780  125 m2 2 Bedrooms Apartments for Rent in Musca...
# 6781                  2BHK Apartment for rent - Bousher
# 6782  280 m2 4 Bedrooms Villa for Rent in Muscat Bosher
#
#                               Location    Price   Size Size_unit Listing_Type  \
# 0                         Ruwi, Muscat      150   70.0    Sq. M.     For Rent
# 1                      Al Hail, Muscat      300  100.0    Sq. M.     For Rent
# 2                        Qurum, Muscat      750  300.0    Sq. M.     For Rent
# 3     Madinat As Sultan Qaboos, Muscat      950  300.0    Sq. M.     For Rent
# 4                  Al Hamriyah, Muscat      250  100.0    Sq. M.     For Rent
# ...                                ...      ...    ...       ...          ...
# 6778            , Al Khuwair, 760832XX  180 OMR  500.0    Sq. M.     For Rent
# 6779                  , Qurm, 905099XX  440 OMR   90.0    Sq. M.     For Rent
# 6780                 , Ghala, 994886XX  230 OMR  125.0    Sq. M.     For Rent
# 6781                , Bosher, 992220XX  270 OMR   80.0    Sq. M.     For Rent
# 6782                , Bosher, 977402XX  950 OMR  280.0    Sq. M.     For Rent
#
#                                                    Link
# 0     https://www.bayut.om/en/property/details-13012...
# 1     https://www.bayut.om/en/property/details-13027...
# 2     https://www.bayut.om/en/property/details-12994...
# 3     https://www.bayut.om/en/property/details-13018...
# 4     https://www.bayut.om/en/property/details-12994...
# ...                                                 ...
# 6778        https://om.opensooq.com/en/search/266994539
# 6779        https://om.opensooq.com/en/search/266949055
# 6780        https://om.opensooq.com/en/search/265445187
# 6781        https://om.opensooq.com/en/search/267036337
# 6782        https://om.opensooq.com/en/search/266989343
#
# [6782 rows x 7 columns]

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6778     True
# 6779     True
# 6780     True
# 6781    False
# 6782     True
# Length: 6782, dtype: bool

# %%
duplicates = df[df.duplicated()]
display(duplicates)
# Out:
#                                                   Title  \
# 264      2 Bedrooms Apartment For Rent in Qurum, Muscat
# 1969  100 m2 1 Bedroom Apartments for Rent in Dhofar...
# 1970         Residential Land for Rent in Dhofar Salala
# 1971  عقود ايجار مكاتب مؤقتة وترخيص الانشطة Temporar...
# 1973  2 Bedrooms Chalet for Rent in Al Dakhiliya Bidbid
# ...                                                 ...
# 6777                  Semi Furnished room in Al khuwair
# 6778  500 m2 Studio Apartments for Rent in Muscat Al...
# 6779  Fully Furnished 1BHK Flat for Rent – Bareeq Al...
# 6780  125 m2 2 Bedrooms Apartments for Rent in Musca...
# 6782  280 m2 4 Bedrooms Villa for Rent in Muscat Bosher
#
#                     Location    Price   Size Size_unit Listing_Type  \
# 264            Qurum, Muscat      425  120.0    Sq. M.     For Rent
# 1969      , Salala, 943126XX   50 OMR  100.0    Sq. M.     For Rent
# 1970      , Salala, 990016XX   35 OMR    NaN    Sq. M.     For Rent
# 1971      , Amerat, 955469XX   75 OMR   20.0    Sq. M.     For Rent
# 1973      , Bidbid, 966934XX   40 OMR  220.0    Sq. M.     For Rent
# ...                      ...      ...    ...       ...          ...
# 6777  , Al Khuwair, 917923XX  120 OMR    NaN    Sq. M.     For Rent
# 6778  , Al Khuwair, 760832XX  180 OMR  500.0    Sq. M.     For Rent
# 6779        , Qurm, 905099XX  440 OMR   90.0    Sq. M.     For Rent
# 6780       , Ghala, 994886XX  230 OMR  125.0    Sq. M.     For Rent
# 6782      , Bosher, 977402XX  950 OMR  280.0    Sq. M.     For Rent
#
#                                                    Link
# 264   https://www.bayut.om/en/property/details-13022...
# 1969        https://om.opensooq.com/en/search/266016495
# 1970        https://om.opensooq.com/en/search/266873893
# 1971        https://om.opensooq.com/en/search/263485983
# 1973        https://om.opensooq.com/en/search/259878571
# ...                                                 ...
# 6777        https://om.opensooq.com/en/search/266932071
# 6778        https://om.opensooq.com/en/search/266994539
# 6779        https://om.opensooq.com/en/search/266949055
# 6780        https://om.opensooq.com/en/search/265445187
# 6782        https://om.opensooq.com/en/search/266989343
#
# [677 rows x 7 columns]

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6768    False
# 6769    False
# 6771    False
# 6772    False
# 6781    False
# Length: 6105, dtype: bool

# %%
num_duplicates = df.duplicated().sum()
print("Number of duplicate rows:", num_duplicates)
# Out:
# Number of duplicate rows: 0

# %%
print(df.isnull().sum())
# Out:
# Title             0
# Location          0
# Price             0
# Size            966
# Size_unit         0
# Listing_Type      0
# Link              0
# dtype: int64

# %%
df[df['Size'].isna()]
# Out:
#                                               Title                 Location  \
# 1307     Residential Land for Rent in Dhofar Salala       , Salala, 990016XX
# 1311               Furnished Daily in Dhofar Salala       , Salala, 990838XX
# 1324          Furnished Daily in Al Dakhiliya Nizwa        , Nizwa, 994282XX
# 1328  Daily room rent. إيجار غرفة يومية في المعبيلة  , Al Maabilah, 780331XX
# 1341               Furnished Daily in Dhofar Salala       , Salala, 762200XX
# ...                                             ...                      ...
# 6752       Unfurnished Monthly in Muscat Al Mawaleh   , Al Mawaleh, 929192XX
# 6755   Semi Furnished Monthly in Al Dakhiliya Manah        , Manah, 989927XX
# 6758          Unfurnished Monthly in Muscat Ghubrah      , Ghubrah, 920335XX
# 6765              Furnished Daily in Muscat Ghubrah      , Ghubrah, 772737XX
# 6767             Furnished Daily in Muscat Al Khoud     , Al Khoud, 921211XX
#
#           Price  Size Size_unit Listing_Type  \
# 1307     35 OMR   NaN    Sq. M.     For Rent
# 1311     50 OMR   NaN    Sq. M.     For Rent
# 1324     12 OMR   NaN    Sq. M.     For Rent
# 1328      6 OMR   NaN    Sq. M.     For Rent
# 1341     15 OMR   NaN    Sq. M.     For Rent
# ...         ...   ...       ...          ...
# 6752    115 OMR   NaN    Sq. M.     For Rent
# 6755  1,500 OMR   NaN    Sq. M.     For Rent
# 6758    120 OMR   NaN    Sq. M.     For Rent
# 6765     27 OMR   NaN    Sq. M.     For Rent
# 6767      7 OMR   NaN    Sq. M.     For Rent
#
#                                              Link
# 1307  https://om.opensooq.com/en/search/266873893
# 1311  https://om.opensooq.com/en/search/266121233
# 1324  https://om.opensooq.com/en/search/256817323
# 1328  https://om.opensooq.com/en/search/266009649
# 1341  https://om.opensooq.com/en/search/265805595
# ...                                           ...
# 6752  https://om.opensooq.com/en/search/263335749
# 6755  https://om.opensooq.com/en/search/264646661
# 6758  https://om.opensooq.com/en/search/264361347
# 6765  https://om.opensooq.com/en/search/262616373
# 6767  https://om.opensooq.com/en/search/250633191
#
# [966 rows x 7 columns]

# %%
median_value = df['Size'].median()


df['Size'].fillna(median_value, inplace=True)
# Out:
# C:\Users\bbuser\AppData\Local\Temp\ipykernel_9012\1253034325.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Size'].fillna(median_value, inplace=True)

# %%
print(df.isnull().sum())
# Out:
# Title           0
# Location        0
# Price           0
# Size            0
# Size_unit       0
# Listing_Type    0
# dtype: int64

# %%
df['Location'] = df['Location'].str.replace(r'[\dxX]+', '', regex=True)
df['Location'] = df['Location'].str.replace(r'[,\s]+$', '', regex=True)    
df['Location'] = df['Location'].str.strip(', ')

# %%
 df= df.drop('Link', axis=1)

# %%
df
# Out:
#                                                   Title  \
# 0                          1 Bedroom Apartment For Rent
# 1                          1 Bedroom Apartment For Rent
# 2                             3 Bedrooms Villa For Rent
# 3                             4 Bedrooms Villa For Rent
# 4                      2 Bedrooms Apartment For Rent in
# ...                                                 ...
# 6768                       3-BEDROOM TOWNHOUSE [WA-155]
# 6769  Exquisite 3-Bedroom Luxury Villa in the Heart ...
# 6771  Luxury furnished apartment for rent - primer L...
# 6772  100 m2 2 Bedrooms Apartments for Rent in Musca...
# 6781                  2BHK Apartment for rent - Bousher
#
#                               Location      Price   Size Size_unit  \
# 0                         Ruwi, Muscat        150   70.0    Sq. M.
# 1                      Al Hail, Muscat        300  100.0    Sq. M.
# 2                        Qurum, Muscat        750  300.0    Sq. M.
# 3     Madinat As Sultan Qaboos, Muscat        950  300.0    Sq. M.
# 4                  Al Hamriyah, Muscat        250  100.0    Sq. M.
# ...                                ...        ...    ...       ...
# 6768                           Al Mouj  1,100 OMR    1.0    Sq. M.
# 6769                           Al Mouj  1,250 OMR  270.0    Sq. M.
# 6771                            Azaiba    500 OMR  145.0    Sq. M.
# 6772                       Al Maabilah    160 OMR  100.0    Sq. M.
# 6781                            Bosher    270 OMR   80.0    Sq. M.
#
#      Listing_Type
# 0        For Rent
# 1        For Rent
# 2        For Rent
# 3        For Rent
# 4        For Rent
# ...           ...
# 6768     For Rent
# 6769     For Rent
# 6771     For Rent
# 6772     For Rent
# 6781     For Rent
#
# [6105 rows x 6 columns]

# %%
df.to_csv('cleaned_properties.csv', index=False, encoding='utf-8-sig')
